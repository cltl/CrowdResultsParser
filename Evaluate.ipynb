# %% [markdown]
# **NOTE** Evaluate all systems against the crowd and compare with entropy.

# %%
import pickle
import json
from collections import defaultdict

# %%
crowd_data_loc="crowd_data"
profiler_data_loc="profiler_data"
givens_file="given.pkl"
predicted_file="predicted.pkl"

# %%
with open('mappings.tsv', 'r') as f:
    mapping_file=f.readlines()
mappings={}
for line in mapping_file:
    uri, old_label, new_label = line.split('\t')
    mappings[uri]=new_label.strip()

# %%
domains={'century':['20', '19', '18', '17', '21'], 
         'lifedur': ['71-80', '81-90', '61-70', '51-60', '91-100', '41-50', 
                      '31-40', '21-30', '101-110', '11-20'],
         'gender': ['Male', 'Female'],
         'politicalparty': ['Democratic Party', 'Republican Party'],
         'occupation': ['politician', 'actor', 'lawyer', 'baseball player', 
                        'American football player', 'singer', 'writer', 
                        'basketball player', 'judge'],
         'birthplace': ['New York City (NY)', 'Chicago (IL)', 'Los Angeles (CA)', 
                        'Philadelphia (PA)', 'Boston (MA)', 'Washington D.C.', 
                        'San Francisco (CA)', 'Detroit (MI)'],
         'deathplace': ['New York City (NY)', 'Chicago (IL)', 'Los Angeles (CA)', 
                        'Philadelphia (PA)', 'Boston (MA)', 'Washington D.C.', 
                        'San Francisco (CA)', 'Santa Monica (CA)'],
         'educatedat': ['Harvard University', 'Columbia University', 'Yale University', 
                        'University of Michigan', 'Stanford University', 
                        'Princeton University', 'University of Wisconsin–Madison', 
                        'University of California, Berkeley', 'Cornell University'],
         'worklocation': ['Washington D.C.', 'New York City (NY)', 
                          'Harrisburg (PA)', 'Sacramento (CA)', 'Austin (TX)', 
                          'Springfield (IL)', 'Tallahassee (FL)', 'Baton Rouge (LA)', 
                          'Montpelier (VT)', 'Phoenix (AZ)'],
         'religion': ['Christianity', 'atheism', 'Judaism', 'Islam']
        }

# %%
properties_mapping={'member of political party': 'politicalparty',
                    'educated at': 'educatedat',
                    'occupation': 'occupation',
                    'work location': 'worklocation',
                    'place of birth': 'birthplace',
                    'place of death': 'deathplace',
                    'lifespan': 'lifedur',
                    'sex or gender': 'gender',
                    'religion': 'religion',
                    'century': 'century'
                   }

# %% [markdown]
# ### 1. Prepare profiler data
#
# #### 1.1. Map URIs to labels

# %%
with open('%s/%s' % (profiler_data_loc, givens_file), 'rb') as f:
    old_prof_givens=pickle.load(f)
with open('%s/%s' % (profiler_data_loc, predicted_file), 'rb') as f:
    old_prof_preds=pickle.load(f,encoding='latin1')

# %%
def map_givens(old_prof_givens):    
    new_prof_givens=[]
    for row in old_prof_givens:
        new_row={}
        for k,v in row.items():
            new_k=properties_mapping[k]
            new_v = mappings[v]
            new_row[new_k]=new_v
        new_prof_givens.append(new_row)
    return new_prof_givens

# %%
def accumulate_and_transpose(new_prof_givens, old_prof_preds):
            
    transposed_prof_predictions=[]
    for x in range(len(new_prof_givens)):
        given_props=new_prof_givens[x].keys()
        needed_props=domains.keys()-given_props
        pred_row={}
        for prop in needed_props:
            pred_row[prop]=new_prof_preds[prop][x]
            pred_row[prop]['None of the above']=max(0,1-sum(pred_row[prop].values()))
        transposed_prof_predictions.append(pred_row)

    return transposed_prof_predictions

# %%
new_prof_givens=map_givens(old_prof_givens)

new_prof_preds=defaultdict(list)
for prop, data in old_prof_preds.items():
    prop=properties_mapping[prop]
    for dist in data:
        new_dist={}
        for k,v in dist:
            if k in mappings.keys() and mappings[k] in domains[prop]:
                new_k=mappings[k]
            else:
                new_k='None of the above'
            if new_k not in new_dist.keys():
                new_dist[new_k]=v
            else:
                new_dist[new_k]+=v
        new_prof_preds[prop].append(new_dist)

transposed_prof_predictions=accumulate_and_transpose(new_prof_givens, new_prof_preds)

# %% [markdown]
# ### 2. Prepare crowd data

# %%
with open('%s/%s' % (crowd_data_loc, givens_file), 'rb') as f:
    old_crowd_givens=pickle.load(f)
    new_crowd_givens=old_crowd_givens
with open('%s/%s' % (crowd_data_loc, predicted_file), 'rb') as f:
    old_crowd_preds=pickle.load(f)

# %%
undecided='I can not decide'
def transform_undecided(prop, dist):
    if undecided in dist.keys():
        new_dist={}
        undecided_part=dist[undecided]
        split_among=len(domains[prop]) + 1
        add_to_each=undecided_part/split_among
        for value in ['None of the above'] + domains[prop]:
            if value in dist.keys():
                new_dist[value]=dist[value]+add_to_each
            else:
                new_dist[value]=add_to_each
        return new_dist
    else:
        return dist

# %%
new_crowd_preds=[]
for row in old_crowd_preds:
    new_row={}
    for prop, dist in row.items():
        new_dist=transform_undecided(prop, dist)
        new_row[prop]=new_dist
    new_crowd_preds.append(new_row)

# %%
new_crowd_preds
# Out:
# [{'birthplace': {'Boston (MA)': 0.38222222222222224,
#    'Chicago (IL)': 0.05222222222222222,
#    'Detroit (MI)': 0.05222222222222222,
#    'Los Angeles (CA)': 0.12222222222222223,
#    'New York City (NY)': 0.12222222222222223,
#    'None of the above': 0.05222222222222222,
#    'Philadelphia (PA)': 0.12222222222222223,
#    'San Francisco (CA)': 0.05222222222222222,
#    'Washington D.C.': 0.05222222222222222},
#   'century': {'17': 0.045000000000000005,
#    '18': 0.11500000000000002,
#    '19': 0.11500000000000002,
#    '20': 0.645,
#    '21': 0.045000000000000005,
#    'None of the above': 0.045000000000000005},
#   'deathplace': {'Boston (MA)': 0.1288888888888889,
#    'Chicago (IL)': 0.05888888888888889,
#    'Los Angeles (CA)': 0.1288888888888889,
#    'New York City (NY)': 0.18888888888888888,
#    'None of the above': 0.1288888888888889,
#    'Philadelphia (PA)': 0.05888888888888889,
#    'San Francisco (CA)': 0.05888888888888889,
#    'Santa Monica (CA)': 0.05888888888888889,
#    'Washington D.C.': 0.18888888888888888},
#   'gender': {'Female': 0.24333333333333335,
#    'Male': 0.7133333333333334,
#    'None of the above': 0.043333333333333335},
#   'lifedur': {'101-110': 0.011818181818181818,
#    '11-20': 0.011818181818181818,
#    '21-30': 0.011818181818181818,
#    '31-40': 0.011818181818181818,
#    '41-50': 0.011818181818181818,
#    '51-60': 0.08181818181818182,
#    '61-70': 0.21181818181818182,
#    '71-80': 0.5418181818181819,
#    '81-90': 0.011818181818181818,
#    '91-100': 0.011818181818181818,
#    'None of the above': 0.08181818181818182},
#   'religion': {'Christianity': 0.654,
#    'Islam': 0.054000000000000006,
#    'Judaism': 0.12400000000000001,
#    'None of the above': 0.054000000000000006,
#    'atheism': 0.12400000000000001},
#   'worklocation': {'Austin (TX)': 0.04818181818181819,
#    'Baton Rouge (LA)': 0.04818181818181819,
#    'Harrisburg (PA)': 0.04818181818181819,
#    'Montpelier (VT)': 0.04818181818181819,
#    'New York City (NY)': 0.2481818181818182,
#    'None of the above': 0.04818181818181819,
#    'Phoenix (AZ)': 0.04818181818181819,
#    'Sacramento (CA)': 0.04818181818181819,
#    'Springfield (IL)': 0.04818181818181819,
#    'Tallahassee (FL)': 0.04818181818181819,
#    'Washington D.C.': 0.31818181818181823}},
#  {'birthplace': {'Boston (MA)': 0.17444444444444446,
#    'Chicago (IL)': 0.044444444444444446,
#    'Detroit (MI)': 0.044444444444444446,
#    'Los Angeles (CA)': 0.044444444444444446,
#    'New York City (NY)': 0.24444444444444446,
#    'None of the above': 0.044444444444444446,
#    'Philadelphia (PA)': 0.11444444444444446,
#    'San Francisco (CA)': 0.044444444444444446,
#    'Washington D.C.': 0.24444444444444446},
#   'century': {'17': 0.021666666666666667,
#    '18': 0.09166666666666667,
#    '19': 0.09166666666666667,
#    '20': 0.7516666666666667,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.12222222222222223,
#    'Chicago (IL)': 0.05222222222222222,
#    'Los Angeles (CA)': 0.05222222222222222,
#    'New York City (NY)': 0.05222222222222222,
#    'None of the above': 0.05222222222222222,
#    'Philadelphia (PA)': 0.05222222222222222,
#    'San Francisco (CA)': 0.05222222222222222,
#    'Santa Monica (CA)': 0.05222222222222222,
#    'Washington D.C.': 0.5222222222222221},
#   'gender': {'Female': 0.19666666666666666,
#    'Male': 0.7366666666666667,
#    'None of the above': 0.06666666666666667},
#   'lifedur': {'101-110': 0.024545454545454547,
#    '11-20': 0.024545454545454547,
#    '21-30': 0.024545454545454547,
#    '31-40': 0.024545454545454547,
#    '41-50': 0.09454545454545456,
#    '51-60': 0.024545454545454547,
#    '61-70': 0.22454545454545455,
#    '71-80': 0.42454545454545456,
#    '81-90': 0.09454545454545456,
#    '91-100': 0.024545454545454547,
#    'None of the above': 0.024545454545454547},
#   'religion': {'Christianity': 0.5499999999999999,
#    'Islam': 0.08,
#    'Judaism': 0.15000000000000002,
#    'None of the above': 0.08,
#    'atheism': 0.15000000000000002}},
#  {'century': {'17': 0.03333333333333333,
#    '18': 0.03333333333333333,
#    '19': 0.10333333333333333,
#    '20': 0.7633333333333333,
#    '21': 0.03333333333333333,
#    'None of the above': 0.03333333333333333},
#   'deathplace': {'Boston (MA)': 0.3066666666666667,
#    'Chicago (IL)': 0.03666666666666667,
#    'Los Angeles (CA)': 0.03666666666666667,
#    'New York City (NY)': 0.03666666666666667,
#    'None of the above': 0.03666666666666667,
#    'Philadelphia (PA)': 0.03666666666666667,
#    'San Francisco (CA)': 0.03666666666666667,
#    'Santa Monica (CA)': 0.03666666666666667,
#    'Washington D.C.': 0.4366666666666667},
#   'gender': {'Female': 0.09333333333333334,
#    'Male': 0.8933333333333333,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.018181818181818184,
#    '11-20': 0.018181818181818184,
#    '21-30': 0.018181818181818184,
#    '31-40': 0.018181818181818184,
#    '41-50': 0.018181818181818184,
#    '51-60': 0.018181818181818184,
#    '61-70': 0.2181818181818182,
#    '71-80': 0.4181818181818182,
#    '81-90': 0.2181818181818182,
#    '91-100': 0.018181818181818184,
#    'None of the above': 0.018181818181818184},
#   'religion': {'Christianity': 0.8140000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.14400000000000002}},
#  {'century': {'17': 0.011666666666666667,
#    '18': 0.011666666666666667,
#    '19': 0.21166666666666667,
#    '20': 0.7416666666666667,
#    '21': 0.011666666666666667,
#    'None of the above': 0.011666666666666667},
#   'deathplace': {'Boston (MA)': 0.22222222222222224,
#    'Chicago (IL)': 0.022222222222222223,
#    'Los Angeles (CA)': 0.022222222222222223,
#    'New York City (NY)': 0.09222222222222223,
#    'None of the above': 0.022222222222222223,
#    'Philadelphia (PA)': 0.022222222222222223,
#    'San Francisco (CA)': 0.022222222222222223,
#    'Santa Monica (CA)': 0.022222222222222223,
#    'Washington D.C.': 0.5522222222222223},
#   'gender': {'Female': 0.023333333333333334,
#    'Male': 0.9533333333333334,
#    'None of the above': 0.023333333333333334},
#   'religion': {'Christianity': 0.8140000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.084,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.084}},
#  {'birthplace': {'Boston (MA)': 0.37444444444444447,
#    'Chicago (IL)': 0.044444444444444446,
#    'Detroit (MI)': 0.044444444444444446,
#    'Los Angeles (CA)': 0.044444444444444446,
#    'New York City (NY)': 0.17444444444444446,
#    'None of the above': 0.044444444444444446,
#    'Philadelphia (PA)': 0.17444444444444446,
#    'San Francisco (CA)': 0.044444444444444446,
#    'Washington D.C.': 0.044444444444444446},
#   'century': {'17': 0.055,
#    '18': 0.125,
#    '19': 0.185,
#    '20': 0.525,
#    '21': 0.055,
#    'None of the above': 0.055},
#   'deathplace': {'Boston (MA)': 0.12222222222222223,
#    'Chicago (IL)': 0.05222222222222222,
#    'Los Angeles (CA)': 0.05222222222222222,
#    'New York City (NY)': 0.18222222222222223,
#    'None of the above': 0.05222222222222222,
#    'Philadelphia (PA)': 0.05222222222222222,
#    'San Francisco (CA)': 0.05222222222222222,
#    'Santa Monica (CA)': 0.05222222222222222,
#    'Washington D.C.': 0.38222222222222224},
#   'gender': {'Female': 0.11333333333333334,
#    'Male': 0.8433333333333334,
#    'None of the above': 0.043333333333333335},
#   'lifedur': {'101-110': 0.030000000000000002,
#    '11-20': 0.030000000000000002,
#    '21-30': 0.030000000000000002,
#    '31-40': 0.030000000000000002,
#    '41-50': 0.030000000000000002,
#    '51-60': 0.1,
#    '61-70': 0.23,
#    '71-80': 0.43000000000000005,
#    '81-90': 0.030000000000000002,
#    '91-100': 0.030000000000000002,
#    'None of the above': 0.030000000000000002},
#   'religion': {'Christianity': 0.896,
#    'Islam': 0.026000000000000002,
#    'Judaism': 0.026000000000000002,
#    'None of the above': 0.026000000000000002,
#    'atheism': 0.026000000000000002},
#   'worklocation': {'Austin (TX)': 0.030000000000000002,
#    'Baton Rouge (LA)': 0.030000000000000002,
#    'Harrisburg (PA)': 0.030000000000000002,
#    'Montpelier (VT)': 0.030000000000000002,
#    'New York City (NY)': 0.1,
#    'None of the above': 0.030000000000000002,
#    'Phoenix (AZ)': 0.030000000000000002,
#    'Sacramento (CA)': 0.030000000000000002,
#    'Springfield (IL)': 0.030000000000000002,
#    'Tallahassee (FL)': 0.030000000000000002,
#    'Washington D.C.': 0.63}},
#  {'birthplace': {'Boston (MA)': 0.16666666666666669,
#    'Chicago (IL)': 0.03666666666666667,
#    'Detroit (MI)': 0.03666666666666667,
#    'Los Angeles (CA)': 0.03666666666666667,
#    'New York City (NY)': 0.16666666666666669,
#    'None of the above': 0.10666666666666667,
#    'Philadelphia (PA)': 0.10666666666666667,
#    'San Francisco (CA)': 0.03666666666666667,
#    'Washington D.C.': 0.3066666666666667},
#   'century': {'17': 0.011666666666666667,
#    '18': 0.08166666666666668,
#    '19': 0.2816666666666667,
#    '20': 0.6116666666666667,
#    '21': 0.011666666666666667,
#    'None of the above': 0.011666666666666667},
#   'deathplace': {'Boston (MA)': 0.030000000000000002,
#    'Chicago (IL)': 0.030000000000000002,
#    'Los Angeles (CA)': 0.030000000000000002,
#    'New York City (NY)': 0.1,
#    'None of the above': 0.1,
#    'Philadelphia (PA)': 0.1,
#    'San Francisco (CA)': 0.030000000000000002,
#    'Santa Monica (CA)': 0.030000000000000002,
#    'Washington D.C.': 0.56},
#   'gender': {'Female': 0.07, 'Male': 0.93},
#   'lifedur': {'101-110': 0.018181818181818184,
#    '11-20': 0.018181818181818184,
#    '21-30': 0.018181818181818184,
#    '31-40': 0.018181818181818184,
#    '41-50': 0.018181818181818184,
#    '51-60': 0.018181818181818184,
#    '61-70': 0.2881818181818182,
#    '71-80': 0.48818181818181816,
#    '81-90': 0.0881818181818182,
#    '91-100': 0.018181818181818184,
#    'None of the above': 0.018181818181818184},
#   'religion': {'Christianity': 0.9440000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'century': {'17': 0.03333333333333333,
#    '18': 0.03333333333333333,
#    '19': 0.16333333333333333,
#    '20': 0.7033333333333334,
#    '21': 0.03333333333333333,
#    'None of the above': 0.03333333333333333},
#   'deathplace': {'Boston (MA)': 0.32222222222222224,
#    'Chicago (IL)': 0.05222222222222222,
#    'Los Angeles (CA)': 0.05222222222222222,
#    'New York City (NY)': 0.05222222222222222,
#    'None of the above': 0.05222222222222222,
#    'Philadelphia (PA)': 0.05222222222222222,
#    'San Francisco (CA)': 0.05222222222222222,
#    'Santa Monica (CA)': 0.05222222222222222,
#    'Washington D.C.': 0.32222222222222224},
#   'gender': {'Female': 0.09333333333333334,
#    'Male': 0.8933333333333333,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.024545454545454547,
#    '11-20': 0.024545454545454547,
#    '21-30': 0.024545454545454547,
#    '31-40': 0.024545454545454547,
#    '41-50': 0.024545454545454547,
#    '51-60': 0.024545454545454547,
#    '61-70': 0.22454545454545455,
#    '71-80': 0.42454545454545456,
#    '81-90': 0.15454545454545454,
#    '91-100': 0.024545454545454547,
#    'None of the above': 0.024545454545454547},
#   'religion': {'Christianity': 0.9440000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'century': {'17': 0.01,
#    '18': 0.13,
#    '19': 0.26,
#    '20': 0.5700000000000001,
#    '21': 0.01,
#    'None of the above': 0.01},
#   'deathplace': {'Boston (MA)': 0.34444444444444444,
#    'Chicago (IL)': 0.034444444444444444,
#    'Los Angeles (CA)': 0.034444444444444444,
#    'New York City (NY)': 0.034444444444444444,
#    'None of the above': 0.034444444444444444,
#    'Philadelphia (PA)': 0.034444444444444444,
#    'San Francisco (CA)': 0.034444444444444444,
#    'Santa Monica (CA)': 0.034444444444444444,
#    'Washington D.C.': 0.41444444444444445},
#   'gender': {'Female': 0.04, 'Male': 0.92, 'None of the above': 0.04},
#   'religion': {'Christianity': 0.952,
#    'Islam': 0.012,
#    'Judaism': 0.012,
#    'None of the above': 0.012,
#    'atheism': 0.012}},
#  {'birthplace': {'Boston (MA)': 0.1288888888888889,
#    'Chicago (IL)': 0.1288888888888889,
#    'Detroit (MI)': 0.05888888888888889,
#    'Los Angeles (CA)': 0.05888888888888889,
#    'New York City (NY)': 0.18888888888888888,
#    'None of the above': 0.1288888888888889,
#    'Philadelphia (PA)': 0.05888888888888889,
#    'San Francisco (CA)': 0.05888888888888889,
#    'Washington D.C.': 0.18888888888888888},
#   'century': {'17': 0.021666666666666667,
#    '18': 0.09166666666666667,
#    '19': 0.22166666666666668,
#    '20': 0.6216666666666666,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.05888888888888889,
#    'Chicago (IL)': 0.05888888888888889,
#    'Los Angeles (CA)': 0.05888888888888889,
#    'New York City (NY)': 0.1288888888888889,
#    'None of the above': 0.1288888888888889,
#    'Philadelphia (PA)': 0.05888888888888889,
#    'San Francisco (CA)': 0.05888888888888889,
#    'Santa Monica (CA)': 0.05888888888888889,
#    'Washington D.C.': 0.3888888888888889},
#   'gender': {'Male': 1.0},
#   'lifedur': {'101-110': 0.024545454545454547,
#    '11-20': 0.024545454545454547,
#    '21-30': 0.024545454545454547,
#    '31-40': 0.024545454545454547,
#    '41-50': 0.024545454545454547,
#    '51-60': 0.09454545454545456,
#    '61-70': 0.35454545454545455,
#    '71-80': 0.35454545454545455,
#    '81-90': 0.024545454545454547,
#    '91-100': 0.024545454545454547,
#    'None of the above': 0.024545454545454547},
#   'religion': {'Christianity': 0.9440000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002},
#   'worklocation': {'Austin (TX)': 0.042727272727272725,
#    'Baton Rouge (LA)': 0.042727272727272725,
#    'Harrisburg (PA)': 0.042727272727272725,
#    'Montpelier (VT)': 0.042727272727272725,
#    'New York City (NY)': 0.11272727272727273,
#    'None of the above': 0.042727272727272725,
#    'Phoenix (AZ)': 0.042727272727272725,
#    'Sacramento (CA)': 0.042727272727272725,
#    'Springfield (IL)': 0.11272727272727273,
#    'Tallahassee (FL)': 0.042727272727272725,
#    'Washington D.C.': 0.44272727272727275}},
#  {'birthplace': {'Boston (MA)': 0.042222222222222223,
#    'Chicago (IL)': 0.6022222222222223,
#    'Detroit (MI)': 0.042222222222222223,
#    'Los Angeles (CA)': 0.042222222222222223,
#    'New York City (NY)': 0.042222222222222223,
#    'None of the above': 0.042222222222222223,
#    'Philadelphia (PA)': 0.042222222222222223,
#    'San Francisco (CA)': 0.042222222222222223,
#    'Washington D.C.': 0.10222222222222221},
#   'century': {'17': 0.03166666666666667,
#    '18': 0.09166666666666667,
#    '19': 0.22166666666666668,
#    '20': 0.5916666666666667,
#    '21': 0.03166666666666667,
#    'None of the above': 0.03166666666666667},
#   'deathplace': {'Boston (MA)': 0.06222222222222223,
#    'Chicago (IL)': 0.37222222222222223,
#    'Los Angeles (CA)': 0.06222222222222223,
#    'New York City (NY)': 0.06222222222222223,
#    'None of the above': 0.18222222222222223,
#    'Philadelphia (PA)': 0.06222222222222223,
#    'San Francisco (CA)': 0.06222222222222223,
#    'Santa Monica (CA)': 0.06222222222222223,
#    'Washington D.C.': 0.06222222222222223},
#   'gender': {'Female': 0.04, 'Male': 0.92, 'None of the above': 0.04},
#   'lifedur': {'101-110': 0.017272727272727273,
#    '11-20': 0.017272727272727273,
#    '21-30': 0.017272727272727273,
#    '31-40': 0.017272727272727273,
#    '41-50': 0.017272727272727273,
#    '51-60': 0.017272727272727273,
#    '61-70': 0.3972727272727273,
#    '71-80': 0.4572727272727273,
#    '81-90': 0.017272727272727273,
#    '91-100': 0.017272727272727273,
#    'None of the above': 0.017272727272727273},
#   'religion': {'Christianity': 0.892,
#    'Islam': 0.072,
#    'Judaism': 0.012,
#    'None of the above': 0.012,
#    'atheism': 0.012}},
#  {'century': {'18': 0.06, '19': 0.25, '20': 0.62, 'None of the above': 0.06},
#   'deathplace': {'Boston (MA)': 0.027777777777777776,
#    'Chicago (IL)': 0.5877777777777778,
#    'Los Angeles (CA)': 0.027777777777777776,
#    'New York City (NY)': 0.027777777777777776,
#    'None of the above': 0.14777777777777779,
#    'Philadelphia (PA)': 0.027777777777777776,
#    'San Francisco (CA)': 0.027777777777777776,
#    'Santa Monica (CA)': 0.027777777777777776,
#    'Washington D.C.': 0.08777777777777777},
#   'gender': {'Female': 0.02, 'Male': 0.96, 'None of the above': 0.02},
#   'lifedur': {'101-110': 0.010909090909090908,
#    '11-20': 0.010909090909090908,
#    '21-30': 0.010909090909090908,
#    '31-40': 0.010909090909090908,
#    '41-50': 0.010909090909090908,
#    '51-60': 0.010909090909090908,
#    '61-70': 0.39090909090909093,
#    '71-80': 0.4509090909090909,
#    '81-90': 0.07090909090909091,
#    '91-100': 0.010909090909090908,
#    'None of the above': 0.010909090909090908},
#   'religion': {'Christianity': 0.892,
#    'Islam': 0.012,
#    'Judaism': 0.072,
#    'None of the above': 0.012,
#    'atheism': 0.012}},
#  {'century': {'17': 0.09166666666666667,
#    '18': 0.021666666666666667,
#    '19': 0.2916666666666667,
#    '20': 0.5516666666666667,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.044444444444444446,
#    'Chicago (IL)': 0.5744444444444444,
#    'Los Angeles (CA)': 0.044444444444444446,
#    'New York City (NY)': 0.044444444444444446,
#    'None of the above': 0.044444444444444446,
#    'Philadelphia (PA)': 0.044444444444444446,
#    'San Francisco (CA)': 0.044444444444444446,
#    'Santa Monica (CA)': 0.044444444444444446,
#    'Washington D.C.': 0.11444444444444446},
#   'gender': {'Male': 1.0},
#   'religion': {'Christianity': 0.9440000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'century': {'17': 0.021666666666666667,
#    '18': 0.09166666666666667,
#    '19': 0.3516666666666667,
#    '20': 0.49166666666666664,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'gender': {'Female': 0.07, 'Male': 0.93},
#   'religion': {'Christianity': 1.0}},
#  {'century': {'17': 0.021666666666666667,
#    '18': 0.021666666666666667,
#    '19': 0.3516666666666667,
#    '20': 0.5516666666666667,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'religion': {'Christianity': 0.9440000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'century': {'17': 0.021666666666666667,
#    '18': 0.15166666666666667,
#    '19': 0.22166666666666668,
#    '20': 0.5516666666666667,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.34444444444444444,
#    'Chicago (IL)': 0.014444444444444446,
#    'Los Angeles (CA)': 0.014444444444444446,
#    'New York City (NY)': 0.014444444444444446,
#    'None of the above': 0.014444444444444446,
#    'Philadelphia (PA)': 0.014444444444444446,
#    'San Francisco (CA)': 0.014444444444444446,
#    'Santa Monica (CA)': 0.014444444444444446,
#    'Washington D.C.': 0.5444444444444445},
#   'gender': {'Male': 1.0},
#   'religion': {'Christianity': 0.93, 'Judaism': 0.07}},
#  {'century': {'17': 0.011666666666666667,
#    '18': 0.08166666666666668,
#    '19': 0.4116666666666667,
#    '20': 0.48166666666666663,
#    '21': 0.011666666666666667,
#    'None of the above': 0.011666666666666667},
#   'gender': {'Female': 0.023333333333333334,
#    'Male': 0.9533333333333334,
#    'None of the above': 0.023333333333333334},
#   'religion': {'Christianity': 1.0}},
#  {'century': {'17': 0.01,
#    '18': 0.13,
#    '19': 0.39,
#    '20': 0.45,
#    '21': 0.01,
#    'None of the above': 0.01},
#   'religion': {'Christianity': 0.952,
#    'Islam': 0.012,
#    'Judaism': 0.012,
#    'None of the above': 0.012,
#    'atheism': 0.012}},
#  {'birthplace': {'Boston (MA)': 0.05888888888888889,
#    'Chicago (IL)': 0.05888888888888889,
#    'Detroit (MI)': 0.05888888888888889,
#    'Los Angeles (CA)': 0.05888888888888889,
#    'New York City (NY)': 0.2588888888888889,
#    'None of the above': 0.18888888888888888,
#    'Philadelphia (PA)': 0.18888888888888888,
#    'San Francisco (CA)': 0.05888888888888889,
#    'Washington D.C.': 0.05888888888888889},
#   'century': {'17': 0.03333333333333333,
#    '18': 0.03333333333333333,
#    '19': 0.16333333333333333,
#    '20': 0.7033333333333334,
#    '21': 0.03333333333333333,
#    'None of the above': 0.03333333333333333},
#   'deathplace': {'Boston (MA)': 0.06666666666666667,
#    'Chicago (IL)': 0.06666666666666667,
#    'Los Angeles (CA)': 0.06666666666666667,
#    'New York City (NY)': 0.19666666666666666,
#    'None of the above': 0.19666666666666666,
#    'Philadelphia (PA)': 0.19666666666666666,
#    'San Francisco (CA)': 0.06666666666666667,
#    'Santa Monica (CA)': 0.06666666666666667,
#    'Washington D.C.': 0.06666666666666667},
#   'gender': {'Female': 0.09000000000000001,
#    'Male': 0.82,
#    'None of the above': 0.09000000000000001},
#   'lifedur': {'101-110': 0.030000000000000002,
#    '11-20': 0.030000000000000002,
#    '21-30': 0.030000000000000002,
#    '31-40': 0.030000000000000002,
#    '41-50': 0.030000000000000002,
#    '51-60': 0.030000000000000002,
#    '61-70': 0.30000000000000004,
#    '71-80': 0.30000000000000004,
#    '81-90': 0.16,
#    '91-100': 0.030000000000000002,
#    'None of the above': 0.030000000000000002},
#   'religion': {'Christianity': 0.736,
#    'Islam': 0.066,
#    'Judaism': 0.066,
#    'None of the above': 0.066,
#    'atheism': 0.066},
#   'worklocation': {'Austin (TX)': 0.042727272727272725,
#    'Baton Rouge (LA)': 0.042727272727272725,
#    'Harrisburg (PA)': 0.11272727272727273,
#    'Montpelier (VT)': 0.042727272727272725,
#    'New York City (NY)': 0.24272727272727274,
#    'None of the above': 0.042727272727272725,
#    'Phoenix (AZ)': 0.042727272727272725,
#    'Sacramento (CA)': 0.042727272727272725,
#    'Springfield (IL)': 0.042727272727272725,
#    'Tallahassee (FL)': 0.042727272727272725,
#    'Washington D.C.': 0.31272727272727274}},
#  {'birthplace': {'Boston (MA)': 0.03666666666666667,
#    'Chicago (IL)': 0.03666666666666667,
#    'Detroit (MI)': 0.03666666666666667,
#    'Los Angeles (CA)': 0.03666666666666667,
#    'New York City (NY)': 0.7066666666666667,
#    'None of the above': 0.03666666666666667,
#    'Philadelphia (PA)': 0.03666666666666667,
#    'San Francisco (CA)': 0.03666666666666667,
#    'Washington D.C.': 0.03666666666666667},
#   'century': {'17': 0.021666666666666667,
#    '18': 0.09166666666666667,
#    '19': 0.15166666666666667,
#    '20': 0.6916666666666667,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.03666666666666667,
#    'Chicago (IL)': 0.03666666666666667,
#    'Los Angeles (CA)': 0.03666666666666667,
#    'New York City (NY)': 0.6366666666666666,
#    'None of the above': 0.03666666666666667,
#    'Philadelphia (PA)': 0.03666666666666667,
#    'San Francisco (CA)': 0.03666666666666667,
#    'Santa Monica (CA)': 0.03666666666666667,
#    'Washington D.C.': 0.10666666666666667},
#   'gender': {'Female': 0.11333333333333334,
#    'Male': 0.8433333333333334,
#    'None of the above': 0.043333333333333335},
#   'lifedur': {'101-110': 0.011818181818181818,
#    '11-20': 0.011818181818181818,
#    '21-30': 0.011818181818181818,
#    '31-40': 0.011818181818181818,
#    '41-50': 0.08181818181818182,
#    '51-60': 0.08181818181818182,
#    '61-70': 0.34181818181818185,
#    '71-80': 0.34181818181818185,
#    '81-90': 0.08181818181818182,
#    '91-100': 0.011818181818181818,
#    'None of the above': 0.011818181818181818},
#   'religion': {'Christianity': 0.744,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.21400000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'century': {'17': 0.021666666666666667,
#    '18': 0.15166666666666667,
#    '19': 0.15166666666666667,
#    '20': 0.6216666666666666,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.014444444444444446,
#    'Chicago (IL)': 0.014444444444444446,
#    'Los Angeles (CA)': 0.014444444444444446,
#    'New York City (NY)': 0.8144444444444445,
#    'None of the above': 0.08444444444444445,
#    'Philadelphia (PA)': 0.014444444444444446,
#    'San Francisco (CA)': 0.014444444444444446,
#    'Santa Monica (CA)': 0.014444444444444446,
#    'Washington D.C.': 0.014444444444444446},
#   'gender': {'Male': 1.0},
#   'lifedur': {'101-110': 0.024545454545454547,
#    '11-20': 0.024545454545454547,
#    '21-30': 0.024545454545454547,
#    '31-40': 0.024545454545454547,
#    '41-50': 0.024545454545454547,
#    '51-60': 0.09454545454545456,
#    '61-70': 0.09454545454545456,
#    '71-80': 0.42454545454545456,
#    '81-90': 0.22454545454545455,
#    '91-100': 0.024545454545454547,
#    'None of the above': 0.024545454545454547},
#   'religion': {'Christianity': 1.0}},
#  {'century': {'18': 0.13, '19': 0.13, '20': 0.6, '21': 0.13},
#   'deathplace': {'Chicago (IL)': 0.07, 'New York City (NY)': 0.93},
#   'gender': {'Female': 0.09333333333333334,
#    'Male': 0.8933333333333333,
#    'None of the above': 0.023333333333333334},
#   'religion': {'Christianity': 0.884,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.084,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'birthplace': {'Boston (MA)': 0.37444444444444447,
#    'Chicago (IL)': 0.044444444444444446,
#    'Detroit (MI)': 0.044444444444444446,
#    'Los Angeles (CA)': 0.044444444444444446,
#    'New York City (NY)': 0.044444444444444446,
#    'None of the above': 0.044444444444444446,
#    'Philadelphia (PA)': 0.17444444444444446,
#    'San Francisco (CA)': 0.044444444444444446,
#    'Washington D.C.': 0.17444444444444446},
#   'century': {'17': 0.03333333333333333,
#    '18': 0.10333333333333333,
#    '19': 0.5033333333333333,
#    '20': 0.30333333333333334,
#    '21': 0.03333333333333333,
#    'None of the above': 0.03333333333333333},
#   'deathplace': {'Boston (MA)': 0.25222222222222224,
#    'Chicago (IL)': 0.05222222222222222,
#    'Los Angeles (CA)': 0.05222222222222222,
#    'New York City (NY)': 0.18222222222222223,
#    'None of the above': 0.12222222222222223,
#    'Philadelphia (PA)': 0.05222222222222222,
#    'San Francisco (CA)': 0.05222222222222222,
#    'Santa Monica (CA)': 0.05222222222222222,
#    'Washington D.C.': 0.18222222222222223},
#   'gender': {'Female': 0.023333333333333334,
#    'Male': 0.9533333333333334,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.018181818181818184,
#    '11-20': 0.018181818181818184,
#    '21-30': 0.018181818181818184,
#    '31-40': 0.018181818181818184,
#    '41-50': 0.018181818181818184,
#    '51-60': 0.018181818181818184,
#    '61-70': 0.48818181818181816,
#    '71-80': 0.3481818181818182,
#    '81-90': 0.018181818181818184,
#    '91-100': 0.018181818181818184,
#    'None of the above': 0.018181818181818184},
#   'religion': {'Christianity': 1.0},
#   'worklocation': {'Austin (TX)': 0.04818181818181819,
#    'Baton Rouge (LA)': 0.04818181818181819,
#    'Harrisburg (PA)': 0.04818181818181819,
#    'Montpelier (VT)': 0.04818181818181819,
#    'New York City (NY)': 0.1181818181818182,
#    'None of the above': 0.04818181818181819,
#    'Phoenix (AZ)': 0.04818181818181819,
#    'Sacramento (CA)': 0.04818181818181819,
#    'Springfield (IL)': 0.04818181818181819,
#    'Tallahassee (FL)': 0.04818181818181819,
#    'Washington D.C.': 0.44818181818181824}},
#  {'birthplace': {'Boston (MA)': 0.17444444444444446,
#    'Chicago (IL)': 0.5144444444444444,
#    'Detroit (MI)': 0.044444444444444446,
#    'Los Angeles (CA)': 0.044444444444444446,
#    'New York City (NY)': 0.044444444444444446,
#    'None of the above': 0.044444444444444446,
#    'Philadelphia (PA)': 0.044444444444444446,
#    'San Francisco (CA)': 0.044444444444444446,
#    'Washington D.C.': 0.044444444444444446},
#   'century': {'17': 0.03333333333333333,
#    '18': 0.10333333333333333,
#    '19': 0.23333333333333334,
#    '20': 0.5633333333333334,
#    '21': 0.03333333333333333,
#    'None of the above': 0.03333333333333333},
#   'deathplace': {'Boston (MA)': 0.05888888888888889,
#    'Chicago (IL)': 0.4588888888888889,
#    'Los Angeles (CA)': 0.05888888888888889,
#    'New York City (NY)': 0.05888888888888889,
#    'None of the above': 0.1288888888888889,
#    'Philadelphia (PA)': 0.05888888888888889,
#    'San Francisco (CA)': 0.05888888888888889,
#    'Santa Monica (CA)': 0.05888888888888889,
#    'Washington D.C.': 0.05888888888888889},
#   'gender': {'Female': 0.023333333333333334,
#    'Male': 0.9533333333333334,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.03636363636363637,
#    '11-20': 0.03636363636363637,
#    '21-30': 0.03636363636363637,
#    '31-40': 0.03636363636363637,
#    '41-50': 0.03636363636363637,
#    '51-60': 0.03636363636363637,
#    '61-70': 0.16636363636363638,
#    '71-80': 0.5063636363636363,
#    '81-90': 0.03636363636363637,
#    '91-100': 0.03636363636363637,
#    'None of the above': 0.03636363636363637},
#   'religion': {'Christianity': 0.9440000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'century': {'17': 0.03333333333333333,
#    '18': 0.03333333333333333,
#    '19': 0.10333333333333333,
#    '20': 0.7033333333333334,
#    '21': 0.03333333333333333,
#    'None of the above': 0.10333333333333333},
#   'deathplace': {'Boston (MA)': 0.022222222222222223,
#    'Chicago (IL)': 0.6222222222222222,
#    'Los Angeles (CA)': 0.022222222222222223,
#    'New York City (NY)': 0.022222222222222223,
#    'None of the above': 0.15222222222222223,
#    'Philadelphia (PA)': 0.022222222222222223,
#    'San Francisco (CA)': 0.022222222222222223,
#    'Santa Monica (CA)': 0.022222222222222223,
#    'Washington D.C.': 0.09222222222222223},
#   'gender': {'Female': 0.043333333333333335,
#    'Male': 0.9133333333333333,
#    'None of the above': 0.043333333333333335},
#   'lifedur': {'101-110': 0.024545454545454547,
#    '11-20': 0.024545454545454547,
#    '21-30': 0.024545454545454547,
#    '31-40': 0.024545454545454547,
#    '41-50': 0.024545454545454547,
#    '51-60': 0.09454545454545456,
#    '61-70': 0.22454545454545455,
#    '71-80': 0.4945454545454545,
#    '81-90': 0.024545454545454547,
#    '91-100': 0.024545454545454547,
#    'None of the above': 0.024545454545454547},
#   'religion': {'Christianity': 0.8400000000000001,
#    'Islam': 0.04,
#    'Judaism': 0.04,
#    'None of the above': 0.04,
#    'atheism': 0.04}},
#  {'century': {'17': 0.021666666666666667,
#    '18': 0.09166666666666667,
#    '19': 0.22166666666666668,
#    '20': 0.6216666666666666,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.014444444444444446,
#    'Chicago (IL)': 0.6144444444444445,
#    'Los Angeles (CA)': 0.014444444444444446,
#    'New York City (NY)': 0.08444444444444445,
#    'None of the above': 0.14444444444444446,
#    'Philadelphia (PA)': 0.014444444444444446,
#    'San Francisco (CA)': 0.014444444444444446,
#    'Santa Monica (CA)': 0.08444444444444445,
#    'Washington D.C.': 0.014444444444444446},
#   'gender': {'Female': 0.09000000000000001,
#    'Male': 0.82,
#    'None of the above': 0.09000000000000001},
#   'religion': {'Christianity': 0.784,
#    'Islam': 0.054000000000000006,
#    'Judaism': 0.054000000000000006,
#    'None of the above': 0.054000000000000006,
#    'atheism': 0.054000000000000006}},
#  {'birthplace': {'Boston (MA)': 0.12222222222222223,
#    'Chicago (IL)': 0.05222222222222222,
#    'Detroit (MI)': 0.12222222222222223,
#    'Los Angeles (CA)': 0.05222222222222222,
#    'New York City (NY)': 0.18222222222222223,
#    'None of the above': 0.05222222222222222,
#    'Philadelphia (PA)': 0.12222222222222223,
#    'San Francisco (CA)': 0.05222222222222222,
#    'Washington D.C.': 0.25222222222222224},
#   'century': {'17': 0.021666666666666667,
#    '18': 0.021666666666666667,
#    '19': 0.15166666666666667,
#    '20': 0.7516666666666667,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.03666666666666667,
#    'Chicago (IL)': 0.03666666666666667,
#    'Los Angeles (CA)': 0.03666666666666667,
#    'New York City (NY)': 0.03666666666666667,
#    'None of the above': 0.03666666666666667,
#    'Philadelphia (PA)': 0.03666666666666667,
#    'San Francisco (CA)': 0.10666666666666667,
#    'Santa Monica (CA)': 0.03666666666666667,
#    'Washington D.C.': 0.6366666666666666},
#   'gender': {'Male': 1.0},
#   'lifedur': {'101-110': 0.024545454545454547,
#    '11-20': 0.024545454545454547,
#    '21-30': 0.024545454545454547,
#    '31-40': 0.024545454545454547,
#    '41-50': 0.024545454545454547,
#    '51-60': 0.024545454545454547,
#    '61-70': 0.29454545454545455,
#    '71-80': 0.42454545454545456,
#    '81-90': 0.09454545454545456,
#    '91-100': 0.024545454545454547,
#    'None of the above': 0.024545454545454547},
#   'religion': {'Christianity': 0.9440000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'century': {'17': 0.03333333333333333,
#    '18': 0.03333333333333333,
#    '19': 0.16333333333333333,
#    '20': 0.7033333333333334,
#    '21': 0.03333333333333333,
#    'None of the above': 0.03333333333333333},
#   'deathplace': {'Boston (MA)': 0.044444444444444446,
#    'Chicago (IL)': 0.044444444444444446,
#    'Los Angeles (CA)': 0.044444444444444446,
#    'New York City (NY)': 0.044444444444444446,
#    'None of the above': 0.11444444444444446,
#    'Philadelphia (PA)': 0.17444444444444446,
#    'San Francisco (CA)': 0.044444444444444446,
#    'Santa Monica (CA)': 0.044444444444444446,
#    'Washington D.C.': 0.4444444444444445},
#   'gender': {'Female': 0.09333333333333334,
#    'Male': 0.8933333333333333,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.024545454545454547,
#    '11-20': 0.024545454545454547,
#    '21-30': 0.024545454545454547,
#    '31-40': 0.024545454545454547,
#    '41-50': 0.024545454545454547,
#    '51-60': 0.09454545454545456,
#    '61-70': 0.35454545454545455,
#    '71-80': 0.35454545454545455,
#    '81-90': 0.024545454545454547,
#    '91-100': 0.024545454545454547,
#    'None of the above': 0.024545454545454547},
#   'religion': {'Christianity': 0.9440000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'century': {'17': 0.08166666666666668,
#    '18': 0.08166666666666668,
#    '19': 0.3416666666666667,
#    '20': 0.4116666666666667,
#    '21': 0.08166666666666668,
#    'None of the above': 0.011666666666666667},
#   'deathplace': {'Boston (MA)': 0.030000000000000002,
#    'Chicago (IL)': 0.030000000000000002,
#    'Los Angeles (CA)': 0.030000000000000002,
#    'New York City (NY)': 0.030000000000000002,
#    'None of the above': 0.030000000000000002,
#    'Philadelphia (PA)': 0.23,
#    'San Francisco (CA)': 0.030000000000000002,
#    'Santa Monica (CA)': 0.030000000000000002,
#    'Washington D.C.': 0.56},
#   'gender': {'Female': 0.13, 'Male': 0.87},
#   'religion': {'Christianity': 0.884,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.084}},
#  {'century': {'18': 0.13, '19': 0.13, '20': 0.6, '21': 0.13},
#   'gender': {'Male': 1.0},
#   'religion': {'Christianity': 0.93, 'None of the above': 0.07}},
#  {'century': {'17': 0.011666666666666667,
#    '18': 0.08166666666666668,
#    '19': 0.14166666666666666,
#    '20': 0.6816666666666668,
#    '21': 0.08166666666666668,
#    'None of the above': 0.011666666666666667},
#   'religion': {'Christianity': 1.0}},
#  {'century': {'17': 0.021666666666666667,
#    '18': 0.09166666666666667,
#    '19': 0.15166666666666667,
#    '20': 0.6216666666666666,
#    '21': 0.021666666666666667,
#    'None of the above': 0.09166666666666667},
#   'deathplace': {'Boston (MA)': 0.2366666666666667,
#    'Chicago (IL)': 0.3066666666666667,
#    'Los Angeles (CA)': 0.03666666666666667,
#    'New York City (NY)': 0.10666666666666667,
#    'None of the above': 0.16666666666666669,
#    'Philadelphia (PA)': 0.03666666666666667,
#    'San Francisco (CA)': 0.03666666666666667,
#    'Santa Monica (CA)': 0.03666666666666667,
#    'Washington D.C.': 0.03666666666666667},
#   'gender': {'Female': 0.13666666666666666,
#    'Male': 0.7966666666666666,
#    'None of the above': 0.06666666666666667},
#   'lifedur': {'101-110': 0.024545454545454547,
#    '11-20': 0.024545454545454547,
#    '21-30': 0.024545454545454547,
#    '31-40': 0.024545454545454547,
#    '41-50': 0.024545454545454547,
#    '51-60': 0.22454545454545455,
#    '61-70': 0.15454545454545454,
#    '71-80': 0.35454545454545455,
#    '81-90': 0.09454545454545456,
#    '91-100': 0.024545454545454547,
#    'None of the above': 0.024545454545454547},
#   'religion': {'Christianity': 0.77,
#    'Islam': 0.04,
#    'Judaism': 0.04,
#    'None of the above': 0.11000000000000001,
#    'atheism': 0.04}},
#  {'century': {'17': 0.011666666666666667,
#    '18': 0.14166666666666666,
#    '19': 0.21166666666666667,
#    '20': 0.6116666666666667,
#    '21': 0.011666666666666667,
#    'None of the above': 0.011666666666666667},
#   'deathplace': {'Boston (MA)': 0.2366666666666667,
#    'Chicago (IL)': 0.5066666666666666,
#    'Los Angeles (CA)': 0.03666666666666667,
#    'New York City (NY)': 0.03666666666666667,
#    'None of the above': 0.03666666666666667,
#    'Philadelphia (PA)': 0.03666666666666667,
#    'San Francisco (CA)': 0.03666666666666667,
#    'Santa Monica (CA)': 0.03666666666666667,
#    'Washington D.C.': 0.03666666666666667},
#   'gender': {'Female': 0.043333333333333335,
#    'Male': 0.9133333333333333,
#    'None of the above': 0.043333333333333335},
#   'religion': {'Christianity': 0.8400000000000001,
#    'Islam': 0.04,
#    'Judaism': 0.04,
#    'None of the above': 0.04,
#    'atheism': 0.04}},
#  {'birthplace': {'Boston (MA)': 0.05888888888888889,
#    'Chicago (IL)': 0.1288888888888889,
#    'Detroit (MI)': 0.4588888888888889,
#    'Los Angeles (CA)': 0.05888888888888889,
#    'New York City (NY)': 0.05888888888888889,
#    'None of the above': 0.05888888888888889,
#    'Philadelphia (PA)': 0.05888888888888889,
#    'San Francisco (CA)': 0.05888888888888889,
#    'Washington D.C.': 0.05888888888888889},
#   'century': {'17': 0.03333333333333333,
#    '18': 0.10333333333333333,
#    '19': 0.10333333333333333,
#    '20': 0.7033333333333334,
#    '21': 0.03333333333333333,
#    'None of the above': 0.03333333333333333},
#   'deathplace': {'Boston (MA)': 0.0811111111111111,
#    'Chicago (IL)': 0.0811111111111111,
#    'Los Angeles (CA)': 0.0811111111111111,
#    'New York City (NY)': 0.1511111111111111,
#    'None of the above': 0.1511111111111111,
#    'Philadelphia (PA)': 0.0811111111111111,
#    'San Francisco (CA)': 0.0811111111111111,
#    'Santa Monica (CA)': 0.0811111111111111,
#    'Washington D.C.': 0.2111111111111111},
#   'gender': {'Female': 0.07, 'Male': 0.93},
#   'lifedur': {'101-110': 0.024545454545454547,
#    '11-20': 0.024545454545454547,
#    '21-30': 0.024545454545454547,
#    '31-40': 0.024545454545454547,
#    '41-50': 0.024545454545454547,
#    '51-60': 0.09454545454545456,
#    '61-70': 0.15454545454545454,
#    '71-80': 0.5545454545454546,
#    '81-90': 0.024545454545454547,
#    '91-100': 0.024545454545454547,
#    'None of the above': 0.024545454545454547},
#   'religion': {'Christianity': 0.9440000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002},
#   'worklocation': {'Austin (TX)': 0.05454545454545454,
#    'Baton Rouge (LA)': 0.05454545454545454,
#    'Harrisburg (PA)': 0.05454545454545454,
#    'Montpelier (VT)': 0.05454545454545454,
#    'New York City (NY)': 0.12454545454545454,
#    'None of the above': 0.12454545454545454,
#    'Phoenix (AZ)': 0.05454545454545454,
#    'Sacramento (CA)': 0.05454545454545454,
#    'Springfield (IL)': 0.12454545454545454,
#    'Tallahassee (FL)': 0.05454545454545454,
#    'Washington D.C.': 0.2545454545454546}},
#  {'birthplace': {'Boston (MA)': 0.022222222222222223,
#    'Chicago (IL)': 0.09222222222222223,
#    'Detroit (MI)': 0.5522222222222223,
#    'Los Angeles (CA)': 0.022222222222222223,
#    'New York City (NY)': 0.022222222222222223,
#    'None of the above': 0.022222222222222223,
#    'Philadelphia (PA)': 0.022222222222222223,
#    'San Francisco (CA)': 0.022222222222222223,
#    'Washington D.C.': 0.22222222222222224},
#   'century': {'17': 0.021666666666666667,
#    '18': 0.09166666666666667,
#    '19': 0.2916666666666667,
#    '20': 0.5516666666666667,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.03666666666666667,
#    'Chicago (IL)': 0.03666666666666667,
#    'Los Angeles (CA)': 0.03666666666666667,
#    'New York City (NY)': 0.03666666666666667,
#    'None of the above': 0.03666666666666667,
#    'Philadelphia (PA)': 0.03666666666666667,
#    'San Francisco (CA)': 0.03666666666666667,
#    'Santa Monica (CA)': 0.03666666666666667,
#    'Washington D.C.': 0.7066666666666667},
#   'gender': {'Female': 0.023333333333333334,
#    'Male': 0.9533333333333334,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.011818181818181818,
#    '11-20': 0.011818181818181818,
#    '21-30': 0.011818181818181818,
#    '31-40': 0.011818181818181818,
#    '41-50': 0.011818181818181818,
#    '51-60': 0.08181818181818182,
#    '61-70': 0.4818181818181818,
#    '71-80': 0.34181818181818185,
#    '81-90': 0.011818181818181818,
#    '91-100': 0.011818181818181818,
#    'None of the above': 0.011818181818181818},
#   'religion': {'Christianity': 1.0}},
#  {'century': {'17': 0.021666666666666667,
#    '18': 0.09166666666666667,
#    '19': 0.09166666666666667,
#    '20': 0.7516666666666667,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.03666666666666667,
#    'Chicago (IL)': 0.03666666666666667,
#    'Los Angeles (CA)': 0.03666666666666667,
#    'New York City (NY)': 0.03666666666666667,
#    'None of the above': 0.16666666666666669,
#    'Philadelphia (PA)': 0.03666666666666667,
#    'San Francisco (CA)': 0.03666666666666667,
#    'Santa Monica (CA)': 0.03666666666666667,
#    'Washington D.C.': 0.5666666666666667},
#   'gender': {'Female': 0.023333333333333334,
#    'Male': 0.9533333333333334,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.011818181818181818,
#    '11-20': 0.011818181818181818,
#    '21-30': 0.011818181818181818,
#    '31-40': 0.011818181818181818,
#    '41-50': 0.011818181818181818,
#    '51-60': 0.08181818181818182,
#    '61-70': 0.34181818181818185,
#    '71-80': 0.41181818181818186,
#    '81-90': 0.08181818181818182,
#    '91-100': 0.011818181818181818,
#    'None of the above': 0.011818181818181818},
#   'religion': {'Christianity': 0.896,
#    'Islam': 0.026000000000000002,
#    'Judaism': 0.026000000000000002,
#    'None of the above': 0.026000000000000002,
#    'atheism': 0.026000000000000002}},
#  {'century': {'17': 0.09166666666666667,
#    '18': 0.021666666666666667,
#    '19': 0.15166666666666667,
#    '20': 0.5516666666666667,
#    '21': 0.15166666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.030000000000000002,
#    'Chicago (IL)': 0.030000000000000002,
#    'Los Angeles (CA)': 0.030000000000000002,
#    'New York City (NY)': 0.030000000000000002,
#    'None of the above': 0.1,
#    'Philadelphia (PA)': 0.030000000000000002,
#    'San Francisco (CA)': 0.030000000000000002,
#    'Santa Monica (CA)': 0.030000000000000002,
#    'Washington D.C.': 0.7000000000000001},
#   'gender': {'Male': 1.0},
#   'religion': {'Christianity': 0.93, 'atheism': 0.07}},
#  {'birthplace': {'Boston (MA)': 0.18222222222222223,
#    'Chicago (IL)': 0.12222222222222223,
#    'Detroit (MI)': 0.06222222222222223,
#    'Los Angeles (CA)': 0.06222222222222223,
#    'New York City (NY)': 0.18222222222222223,
#    'None of the above': 0.06222222222222223,
#    'Philadelphia (PA)': 0.18222222222222223,
#    'San Francisco (CA)': 0.06222222222222223,
#    'Washington D.C.': 0.06222222222222223},
#   'deathplace': {'Boston (MA)': 0.26666666666666666,
#    'Chicago (IL)': 0.07666666666666666,
#    'Los Angeles (CA)': 0.07666666666666666,
#    'New York City (NY)': 0.19666666666666666,
#    'None of the above': 0.07666666666666666,
#    'Philadelphia (PA)': 0.07666666666666666,
#    'San Francisco (CA)': 0.07666666666666666,
#    'Santa Monica (CA)': 0.07666666666666666,
#    'Washington D.C.': 0.07666666666666666},
#   'educatedat': {'Columbia University': 0.122,
#    'Cornell University': 0.062,
#    'Harvard University': 0.062,
#    'None of the above': 0.252,
#    'Princeton University': 0.062,
#    'Stanford University': 0.062,
#    'University of California, Berkeley': 0.062,
#    'University of Michigan': 0.122,
#    'University of Wisconsin–Madison': 0.062,
#    'Yale University': 0.122},
#   'lifedur': {'101-110': 0.010909090909090908,
#    '11-20': 0.010909090909090908,
#    '21-30': 0.010909090909090908,
#    '31-40': 0.1309090909090909,
#    '41-50': 0.1309090909090909,
#    '51-60': 0.2009090909090909,
#    '61-70': 0.2009090909090909,
#    '71-80': 0.1309090909090909,
#    '81-90': 0.1309090909090909,
#    '91-100': 0.010909090909090908,
#    'None of the above': 0.010909090909090908},
#   'occupation': {'American football player': 0.05,
#    'None of the above': 0.24,
#    'actor': 0.05,
#    'baseball player': 0.05,
#    'basketball player': 0.05,
#    'judge': 0.05,
#    'lawyer': 0.05,
#    'politician': 0.11,
#    'singer': 0.11,
#    'writer': 0.24},
#   'politicalparty': {'Democratic Party': 0.3766666666666667,
#    'None of the above': 0.24666666666666667,
#    'Republican Party': 0.3766666666666667},
#   'worklocation': {'Austin (TX)': 0.056363636363636366,
#    'Baton Rouge (LA)': 0.056363636363636366,
#    'Harrisburg (PA)': 0.11636363636363636,
#    'Montpelier (VT)': 0.11636363636363636,
#    'New York City (NY)': 0.17636363636363636,
#    'None of the above': 0.11636363636363636,
#    'Phoenix (AZ)': 0.056363636363636366,
#    'Sacramento (CA)': 0.056363636363636366,
#    'Springfield (IL)': 0.056363636363636366,
#    'Tallahassee (FL)': 0.11636363636363636,
#    'Washington D.C.': 0.056363636363636366}},
#  {'birthplace': {'Boston (MA)': 0.022222222222222223,
#    'Chicago (IL)': 0.022222222222222223,
#    'Detroit (MI)': 0.022222222222222223,
#    'Los Angeles (CA)': 0.09222222222222223,
#    'New York City (NY)': 0.7522222222222222,
#    'None of the above': 0.022222222222222223,
#    'Philadelphia (PA)': 0.022222222222222223,
#    'San Francisco (CA)': 0.022222222222222223,
#    'Washington D.C.': 0.022222222222222223},
#   'educatedat': {'Columbia University': 0.06,
#    'Cornell University': 0.06,
#    'Harvard University': 0.13,
#    'None of the above': 0.33,
#    'Princeton University': 0.06,
#    'Stanford University': 0.06,
#    'University of California, Berkeley': 0.06,
#    'University of Michigan': 0.06,
#    'University of Wisconsin–Madison': 0.06,
#    'Yale University': 0.13},
#   'lifedur': {'101-110': 0.09454545454545456,
#    '11-20': 0.024545454545454547,
#    '21-30': 0.024545454545454547,
#    '31-40': 0.024545454545454547,
#    '41-50': 0.09454545454545456,
#    '51-60': 0.15454545454545454,
#    '61-70': 0.22454545454545455,
#    '71-80': 0.22454545454545455,
#    '81-90': 0.024545454545454547,
#    '91-100': 0.09454545454545456,
#    'None of the above': 0.024545454545454547},
#   'occupation': {'American football player': 0.053000000000000005,
#    'None of the above': 0.183,
#    'actor': 0.183,
#    'baseball player': 0.053000000000000005,
#    'basketball player': 0.053000000000000005,
#    'judge': 0.12300000000000001,
#    'lawyer': 0.12300000000000001,
#    'politician': 0.053000000000000005,
#    'singer': 0.12300000000000001,
#    'writer': 0.053000000000000005},
#   'politicalparty': {'Democratic Party': 0.38,
#    'None of the above': 0.18,
#    'Republican Party': 0.44},
#   'worklocation': {'Austin (TX)': 0.011818181818181818,
#    'Baton Rouge (LA)': 0.011818181818181818,
#    'Harrisburg (PA)': 0.011818181818181818,
#    'Montpelier (VT)': 0.011818181818181818,
#    'New York City (NY)': 0.8118181818181819,
#    'None of the above': 0.08181818181818182,
#    'Phoenix (AZ)': 0.011818181818181818,
#    'Sacramento (CA)': 0.011818181818181818,
#    'Springfield (IL)': 0.011818181818181818,
#    'Tallahassee (FL)': 0.011818181818181818,
#    'Washington D.C.': 0.011818181818181818}},
#  {'birthplace': {'Boston (MA)': 0.021111111111111112,
#    'Chicago (IL)': 0.021111111111111112,
#    'Detroit (MI)': 0.021111111111111112,
#    'Los Angeles (CA)': 0.021111111111111112,
# ...
#    '21-30': 0.018181818181818184,
#    '31-40': 0.018181818181818184,
#    '41-50': 0.018181818181818184,
#    '51-60': 0.0881818181818182,
#    '61-70': 0.2881818181818182,
#    '71-80': 0.4181818181818182,
#    '81-90': 0.0881818181818182,
#    '91-100': 0.018181818181818184,
#    'None of the above': 0.018181818181818184},
#   'religion': {'Christianity': 0.756,
#    'Islam': 0.026000000000000002,
#    'Judaism': 0.156,
#    'None of the above': 0.026000000000000002,
#    'atheism': 0.026000000000000002}},
#  {'century': {'17': 0.011666666666666667,
#    '18': 0.011666666666666667,
#    '19': 0.14166666666666666,
#    '20': 0.8116666666666668,
#    '21': 0.011666666666666667,
#    'None of the above': 0.011666666666666667},
#   'deathplace': {'Boston (MA)': 0.014444444444444446,
#    'Chicago (IL)': 0.014444444444444446,
#    'Los Angeles (CA)': 0.014444444444444446,
#    'New York City (NY)': 0.014444444444444446,
#    'None of the above': 0.014444444444444446,
#    'Philadelphia (PA)': 0.014444444444444446,
#    'San Francisco (CA)': 0.014444444444444446,
#    'Santa Monica (CA)': 0.014444444444444446,
#    'Washington D.C.': 0.8844444444444445},
#   'gender': {'Female': 0.043333333333333335,
#    'Male': 0.9133333333333333,
#    'None of the above': 0.043333333333333335},
#   'lifedur': {'101-110': 0.018181818181818184,
#    '11-20': 0.018181818181818184,
#    '21-30': 0.018181818181818184,
#    '31-40': 0.018181818181818184,
#    '41-50': 0.018181818181818184,
#    '51-60': 0.018181818181818184,
#    '61-70': 0.2881818181818182,
#    '71-80': 0.4181818181818182,
#    '81-90': 0.1481818181818182,
#    '91-100': 0.018181818181818184,
#    'None of the above': 0.018181818181818184},
#   'religion': {'Christianity': 0.896,
#    'Islam': 0.026000000000000002,
#    'Judaism': 0.026000000000000002,
#    'None of the above': 0.026000000000000002,
#    'atheism': 0.026000000000000002}},
#  {'century': {'18': 0.07, '19': 0.2, '20': 0.8},
#   'deathplace': {'Boston (MA)': 0.014444444444444446,
#    'Chicago (IL)': 0.014444444444444446,
#    'Los Angeles (CA)': 0.014444444444444446,
#    'New York City (NY)': 0.014444444444444446,
#    'None of the above': 0.014444444444444446,
#    'Philadelphia (PA)': 0.014444444444444446,
#    'San Francisco (CA)': 0.014444444444444446,
#    'Santa Monica (CA)': 0.014444444444444446,
#    'Washington D.C.': 0.8844444444444445},
#   'gender': {'Female': 0.023333333333333334,
#    'Male': 0.9533333333333334,
#    'None of the above': 0.023333333333333334},
#   'religion': {'Christianity': 0.896,
#    'Islam': 0.026000000000000002,
#    'Judaism': 0.026000000000000002,
#    'None of the above': 0.026000000000000002,
#    'atheism': 0.026000000000000002}},
#  {'century': {'19': 0.2, '20': 0.73, '21': 0.07},
#   'gender': {'Female': 0.07, 'Male': 0.93},
#   'religion': {'Christianity': 0.93, 'Judaism': 0.07}},
#  {'century': {'19': 0.13, '20': 0.87},
#   'religion': {'Christianity': 0.9440000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'century': {'19': 0.13, '20': 0.8, '21': 0.07},
#   'gender': {'Male': 1.0},
#   'religion': {'Christianity': 0.884,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.084,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'century': {'19': 0.33, '20': 0.6, '21': 0.07},
#   'religion': {'Christianity': 0.93, 'Judaism': 0.07}},
#  {'century': {'18': 0.07, '19': 0.2, '20': 0.6, '21': 0.13},
#   'deathplace': {'Boston (MA)': 0.16,
#    'Chicago (IL)': 0.030000000000000002,
#    'Los Angeles (CA)': 0.030000000000000002,
#    'New York City (NY)': 0.1,
#    'None of the above': 0.030000000000000002,
#    'Philadelphia (PA)': 0.030000000000000002,
#    'San Francisco (CA)': 0.1,
#    'Santa Monica (CA)': 0.030000000000000002,
#    'Washington D.C.': 0.5},
#   'gender': {'Male': 1.0},
#   'religion': {'Christianity': 0.744,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.084,
#    'None of the above': 0.084,
#    'atheism': 0.084}},
#  {'century': {'18': 0.07, '19': 0.27, '20': 0.67},
#   'gender': {'Male': 1.0},
#   'religion': {'Christianity': 0.93, 'atheism': 0.07}},
#  {'century': {'19': 0.4, '20': 0.53, '21': 0.07},
#   'religion': {'Christianity': 0.9440000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.014000000000000002,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'birthplace': {'Boston (MA)': 0.1,
#    'Chicago (IL)': 0.030000000000000002,
#    'Detroit (MI)': 0.030000000000000002,
#    'Los Angeles (CA)': 0.030000000000000002,
#    'New York City (NY)': 0.5,
#    'None of the above': 0.030000000000000002,
#    'Philadelphia (PA)': 0.1,
#    'San Francisco (CA)': 0.030000000000000002,
#    'Washington D.C.': 0.16},
#   'century': {'17': 0.011666666666666667,
#    '18': 0.011666666666666667,
#    '19': 0.08166666666666668,
#    '20': 0.8816666666666667,
#    '21': 0.011666666666666667,
#    'None of the above': 0.011666666666666667},
#   'deathplace': {'Boston (MA)': 0.11444444444444446,
#    'Chicago (IL)': 0.044444444444444446,
#    'Los Angeles (CA)': 0.044444444444444446,
#    'New York City (NY)': 0.37444444444444447,
#    'None of the above': 0.11444444444444446,
#    'Philadelphia (PA)': 0.044444444444444446,
#    'San Francisco (CA)': 0.044444444444444446,
#    'Santa Monica (CA)': 0.044444444444444446,
#    'Washington D.C.': 0.17444444444444446},
#   'gender': {'Female': 0.22333333333333336,
#    'Male': 0.7533333333333333,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.018181818181818184,
#    '11-20': 0.018181818181818184,
#    '21-30': 0.018181818181818184,
#    '31-40': 0.018181818181818184,
#    '41-50': 0.018181818181818184,
#    '51-60': 0.0881818181818182,
#    '61-70': 0.2181818181818182,
#    '71-80': 0.4181818181818182,
#    '81-90': 0.1481818181818182,
#    '91-100': 0.018181818181818184,
#    'None of the above': 0.018181818181818184},
#   'religion': {'Christianity': 0.756,
#    'Islam': 0.026000000000000002,
#    'Judaism': 0.096,
#    'None of the above': 0.026000000000000002,
#    'atheism': 0.096},
#   'worklocation': {'Austin (TX)': 0.03636363636363637,
#    'Baton Rouge (LA)': 0.03636363636363637,
#    'Harrisburg (PA)': 0.03636363636363637,
#    'Montpelier (VT)': 0.03636363636363637,
#    'New York City (NY)': 0.03636363636363637,
#    'None of the above': 0.03636363636363637,
#    'Phoenix (AZ)': 0.03636363636363637,
#    'Sacramento (CA)': 0.03636363636363637,
#    'Springfield (IL)': 0.03636363636363637,
#    'Tallahassee (FL)': 0.03636363636363637,
#    'Washington D.C.': 0.6363636363636364}},
#  {'birthplace': {'Boston (MA)': 0.16,
#    'Chicago (IL)': 0.030000000000000002,
#    'Detroit (MI)': 0.030000000000000002,
#    'Los Angeles (CA)': 0.030000000000000002,
#    'New York City (NY)': 0.36000000000000004,
#    'None of the above': 0.030000000000000002,
#    'Philadelphia (PA)': 0.16,
#    'San Francisco (CA)': 0.030000000000000002,
#    'Washington D.C.': 0.16},
#   'century': {'17': 0.021666666666666667,
#    '18': 0.021666666666666667,
#    '19': 0.22166666666666668,
#    '20': 0.6916666666666667,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.022222222222222223,
#    'Chicago (IL)': 0.022222222222222223,
#    'Los Angeles (CA)': 0.022222222222222223,
#    'New York City (NY)': 0.09222222222222223,
#    'None of the above': 0.022222222222222223,
#    'Philadelphia (PA)': 0.022222222222222223,
#    'San Francisco (CA)': 0.022222222222222223,
#    'Santa Monica (CA)': 0.022222222222222223,
#    'Washington D.C.': 0.7522222222222222},
#   'gender': {'Female': 0.29333333333333333,
#    'Male': 0.6933333333333334,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.011818181818181818,
#    '11-20': 0.011818181818181818,
#    '21-30': 0.011818181818181818,
#    '31-40': 0.011818181818181818,
#    '41-50': 0.011818181818181818,
#    '51-60': 0.011818181818181818,
#    '61-70': 0.34181818181818185,
#    '71-80': 0.34181818181818185,
#    '81-90': 0.21181818181818182,
#    '91-100': 0.011818181818181818,
#    'None of the above': 0.011818181818181818},
#   'religion': {'Christianity': 0.8400000000000001,
#    'Islam': 0.04,
#    'Judaism': 0.04,
#    'None of the above': 0.04,
#    'atheism': 0.04}},
#  {'century': {'17': 0.011666666666666667,
#    '18': 0.011666666666666667,
#    '19': 0.14166666666666666,
#    '20': 0.7416666666666667,
#    '21': 0.08166666666666668,
#    'None of the above': 0.011666666666666667},
#   'deathplace': {'Boston (MA)': 0.022222222222222223,
#    'Chicago (IL)': 0.022222222222222223,
#    'Los Angeles (CA)': 0.022222222222222223,
#    'New York City (NY)': 0.2922222222222222,
#    'None of the above': 0.022222222222222223,
#    'Philadelphia (PA)': 0.022222222222222223,
#    'San Francisco (CA)': 0.022222222222222223,
#    'Santa Monica (CA)': 0.022222222222222223,
#    'Washington D.C.': 0.5522222222222223},
#   'gender': {'Female': 0.22333333333333336,
#    'Male': 0.7533333333333333,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.011818181818181818,
#    '11-20': 0.011818181818181818,
#    '21-30': 0.011818181818181818,
#    '31-40': 0.011818181818181818,
#    '41-50': 0.011818181818181818,
#    '51-60': 0.011818181818181818,
#    '61-70': 0.21181818181818182,
#    '71-80': 0.4818181818181818,
#    '81-90': 0.21181818181818182,
#    '91-100': 0.011818181818181818,
#    'None of the above': 0.011818181818181818},
#   'religion': {'Christianity': 0.884,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.084,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'century': {'18': 0.2, '19': 0.13, '20': 0.67},
#   'deathplace': {'Boston (MA)': 0.014444444444444446,
#    'Chicago (IL)': 0.014444444444444446,
#    'Los Angeles (CA)': 0.014444444444444446,
#    'New York City (NY)': 0.28444444444444444,
#    'None of the above': 0.014444444444444446,
#    'Philadelphia (PA)': 0.014444444444444446,
#    'San Francisco (CA)': 0.014444444444444446,
#    'Santa Monica (CA)': 0.014444444444444446,
#    'Washington D.C.': 0.6144444444444445},
#   'gender': {'Male': 1.0},
#   'religion': {'Christianity': 0.884,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.084,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.014000000000000002}},
#  {'birthplace': {'Boston (MA)': 0.03666666666666667,
#    'Chicago (IL)': 0.03666666666666667,
#    'Detroit (MI)': 0.03666666666666667,
#    'Los Angeles (CA)': 0.03666666666666667,
#    'New York City (NY)': 0.5666666666666667,
#    'None of the above': 0.10666666666666667,
#    'Philadelphia (PA)': 0.03666666666666667,
#    'San Francisco (CA)': 0.03666666666666667,
#    'Washington D.C.': 0.10666666666666667},
#   'century': {'17': 0.021666666666666667,
#    '18': 0.021666666666666667,
#    '19': 0.09166666666666667,
#    '20': 0.8216666666666668,
#    '21': 0.021666666666666667,
#    'None of the above': 0.021666666666666667},
#   'deathplace': {'Boston (MA)': 0.05888888888888889,
#    'Chicago (IL)': 0.05888888888888889,
#    'Los Angeles (CA)': 0.05888888888888889,
#    'New York City (NY)': 0.3288888888888889,
#    'None of the above': 0.05888888888888889,
#    'Philadelphia (PA)': 0.05888888888888889,
#    'San Francisco (CA)': 0.05888888888888889,
#    'Santa Monica (CA)': 0.05888888888888889,
#    'Washington D.C.': 0.2588888888888889},
#   'gender': {'Female': 0.09333333333333334,
#    'Male': 0.8933333333333333,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.011818181818181818,
#    '11-20': 0.011818181818181818,
#    '21-30': 0.011818181818181818,
#    '31-40': 0.011818181818181818,
#    '41-50': 0.011818181818181818,
#    '51-60': 0.011818181818181818,
#    '61-70': 0.28181818181818186,
#    '71-80': 0.41181818181818186,
#    '81-90': 0.21181818181818182,
#    '91-100': 0.011818181818181818,
#    'None of the above': 0.011818181818181818},
#   'religion': {'Christianity': 0.756,
#    'Islam': 0.026000000000000002,
#    'Judaism': 0.096,
#    'None of the above': 0.026000000000000002,
#    'atheism': 0.096},
#   'worklocation': {'Austin (TX)': 0.030000000000000002,
#    'Baton Rouge (LA)': 0.030000000000000002,
#    'Harrisburg (PA)': 0.030000000000000002,
#    'Montpelier (VT)': 0.030000000000000002,
#    'New York City (NY)': 0.36000000000000004,
#    'None of the above': 0.030000000000000002,
#    'Phoenix (AZ)': 0.030000000000000002,
#    'Sacramento (CA)': 0.030000000000000002,
#    'Springfield (IL)': 0.030000000000000002,
#    'Tallahassee (FL)': 0.030000000000000002,
#    'Washington D.C.': 0.36000000000000004}},
#  {'birthplace': {'Boston (MA)': 0.13777777777777778,
#    'Chicago (IL)': 0.007777777777777778,
#    'Detroit (MI)': 0.007777777777777778,
#    'Los Angeles (CA)': 0.07777777777777778,
#    'New York City (NY)': 0.20777777777777778,
#    'None of the above': 0.4077777777777778,
#    'Philadelphia (PA)': 0.07777777777777778,
#    'San Francisco (CA)': 0.07777777777777778,
#    'Washington D.C.': 0.007777777777777778},
#   'century': {'17': 0.011666666666666667,
#    '18': 0.011666666666666667,
#    '19': 0.21166666666666667,
#    '20': 0.6816666666666668,
#    '21': 0.08166666666666668,
#    'None of the above': 0.011666666666666667},
#   'deathplace': {'Boston (MA)': 0.08444444444444445,
#    'Chicago (IL)': 0.014444444444444446,
#    'Los Angeles (CA)': 0.014444444444444446,
#    'New York City (NY)': 0.14444444444444446,
#    'None of the above': 0.5444444444444445,
#    'Philadelphia (PA)': 0.014444444444444446,
#    'San Francisco (CA)': 0.08444444444444445,
#    'Santa Monica (CA)': 0.08444444444444445,
#    'Washington D.C.': 0.014444444444444446},
#   'gender': {'Female': 0.29333333333333333,
#    'Male': 0.6933333333333334,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.006363636363636364,
#    '11-20': 0.006363636363636364,
#    '21-30': 0.006363636363636364,
#    '31-40': 0.006363636363636364,
#    '41-50': 0.006363636363636364,
#    '51-60': 0.07636363636363637,
#    '61-70': 0.13636363636363638,
#    '71-80': 0.6063636363636363,
#    '81-90': 0.13636363636363638,
#    '91-100': 0.006363636363636364,
#    'None of the above': 0.006363636363636364},
#   'religion': {'Christianity': 0.756,
#    'Islam': 0.026000000000000002,
#    'Judaism': 0.026000000000000002,
#    'None of the above': 0.096,
#    'atheism': 0.096}},
#  {'century': {'17': 0.011666666666666667,
#    '18': 0.011666666666666667,
#    '19': 0.21166666666666667,
#    '20': 0.6816666666666668,
#    '21': 0.08166666666666668,
#    'None of the above': 0.011666666666666667},
#   'deathplace': {'Boston (MA)': 0.10666666666666667,
#    'Chicago (IL)': 0.03666666666666667,
#    'Los Angeles (CA)': 0.2366666666666667,
#    'New York City (NY)': 0.2366666666666667,
#    'None of the above': 0.2366666666666667,
#    'Philadelphia (PA)': 0.03666666666666667,
#    'San Francisco (CA)': 0.03666666666666667,
#    'Santa Monica (CA)': 0.03666666666666667,
#    'Washington D.C.': 0.03666666666666667},
#   'gender': {'Female': 0.22333333333333336,
#    'Male': 0.7533333333333333,
#    'None of the above': 0.023333333333333334},
#   'lifedur': {'101-110': 0.024545454545454547,
#    '11-20': 0.024545454545454547,
#    '21-30': 0.024545454545454547,
#    '31-40': 0.024545454545454547,
#    '41-50': 0.024545454545454547,
#    '51-60': 0.09454545454545456,
#    '61-70': 0.22454545454545455,
#    '71-80': 0.4945454545454545,
#    '81-90': 0.024545454545454547,
#    '91-100': 0.024545454545454547,
#    'None of the above': 0.024545454545454547},
#   'religion': {'Christianity': 0.8140000000000001,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.084,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.084}},
#  {'century': {'19': 0.13, '20': 0.87},
#   'deathplace': {'Boston (MA)': 0.007777777777777778,
#    'Chicago (IL)': 0.007777777777777778,
#    'Los Angeles (CA)': 0.13777777777777778,
#    'New York City (NY)': 0.4077777777777778,
#    'None of the above': 0.4077777777777778,
#    'Philadelphia (PA)': 0.007777777777777778,
#    'San Francisco (CA)': 0.007777777777777778,
#    'Santa Monica (CA)': 0.007777777777777778,
#    'Washington D.C.': 0.007777777777777778},
#   'gender': {'Female': 0.07, 'Male': 0.93},
#   'religion': {'Christianity': 0.744,
#    'Islam': 0.014000000000000002,
#    'Judaism': 0.084,
#    'None of the above': 0.014000000000000002,
#    'atheism': 0.14400000000000002}}]

# %% [markdown]
# ### 3. Prepare for evaluation

# %%
# Check if the order is the same in both data pieces
for x in range(len(new_crowd_givens)):
    print(new_crowd_givens[x]==new_prof_givens[x])
print(len(new_crowd_givens))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# 305

# %%
def prob_to_list(data, prop_domains):
    size=len(prop_domains)+1
    probs=[0]*size
    
    
    for value, probability in data.items():
        if value=='University of California Berkeley':
            value='University of California, Berkeley'
        if value=='None of the above':
            index=-1
        else:
            index = prop_domains.index(value)
        probs[index]=probability
    return probs

# %%
props = list(properties_mapping.values())[::-1]
props
# Out:
# ['century',
#  'religion',
#  'gender',
#  'lifedur',
#  'deathplace',
#  'birthplace',
#  'worklocation',
#  'occupation',
#  'educatedat',
#  'politicalparty']

# %%
import evaluation
import math
from sklearn.metrics import mutual_info_score
from scipy.spatial.distance import cosine

def compute_divergencies(system, gold, givens, props, metric='js_div'):
    divergencies = defaultdict(list)
    
    divergencies_on_known={}
    
    uncertainties={}
    
    for p in props:
        divergencies_on_known[p]=defaultdict(list)
        uncertainties[p]=defaultdict(list)
    
    for x in range(len(givens)):
        profiler_predictions=system[x]
        crowd_predictions=gold[x]
        
        for prop in crowd_predictions.keys():
            crowd_prop_predictions=crowd_predictions[prop]
            prof_prop_predictions=profiler_predictions[prop]
            crowd_probs=prob_to_list(crowd_prop_predictions, domains[prop])
            prof_probs=prob_to_list(prof_prop_predictions, domains[prop])

            if metric=='js_div':
                div=evaluation.js(crowd_probs, prof_probs)
            elif metric=='js_dist':
                tmp_div=evaluation.js(crowd_probs, prof_probs)
                div=math.sqrt(tmp_div)
            elif metric=='kl_div':
                div=evaluation.kl(crowd_probs, prof_probs)
            elif metric=='kl_max':
                div=evaluation.kl_max(crowd_probs, prof_probs)
            elif metric=='kl_avg':
                div=evaluation.kl_avg(crowd_probs, prof_probs)
            elif metric=='cos':
                div=cosine(crowd_probs, prof_probs)
            divergencies[prop].append(div)
            
            known_props=len(givens[x])
            divergencies_on_known[prop][known_props].append(div)
            
            unc=0.0
            if 'None of the above' in crowd_predictions[prop]:
                unc=crowd_predictions[prop]['None of the above']
            uncertainties[prop][known_props].append(unc)

    return divergencies, divergencies_on_known, uncertainties

# %%
def compute_mean_per_prop(data):
    prop_divs={}
    for prop, divs in data.items():
        avg_div=round(sum(divs)/len(divs),2)
#        print(prop, '\t', avg_div)
        prop_divs[prop]=avg_div
    return prop_divs

# %%
metrics=['js_div', 'js_dist', 'kl_div', 'kl_max', 'kl_avg', 'cos']
div_per_metric={}
div_array_per_metric={}
js_dist_ae=[]
for metric in metrics:
    divergencies, div_known, uncertainties = compute_divergencies(transposed_prof_predictions, 
                                                                new_crowd_preds, 
                                                                new_crowd_givens, 
                                                                props, metric=metric)
    
    mean_values=compute_mean_per_prop(divergencies)
    if metric in ['js_div', 'js_dist']:
        print(metric, mean_values)
        if metric =='js_dist':
            for prop in props:
                js_dist_ae.append(mean_values[prop])
    div_per_metric[metric]=mean_values
    div_array_per_metric[metric]=list(mean_values.values())
# Out:
# js_div {'century': 0.12, 'religion': 0.06, 'gender': 0.02, 'deathplace': 0.16, 'lifedur': 0.09, 'birthplace': 0.24, 'worklocation': 0.3, 'occupation': 0.32, 'educatedat': 0.23, 'politicalparty': 0.06}
# js_dist {'century': 0.32, 'religion': 0.22, 'gender': 0.13, 'deathplace': 0.39, 'lifedur': 0.3, 'birthplace': 0.48, 'worklocation': 0.52, 'occupation': 0.56, 'educatedat': 0.47, 'politicalparty': 0.22}

# %%
from scipy.stats import spearmanr, pearsonr

pearson_correlations = [[' '] + metrics]
spearman_correlations = [[' '] + metrics]

for metric1, dist1 in div_array_per_metric.items():
    pearson_row=[metric1]
    spearman_row=[metric1]
    for metric2, dist2 in div_array_per_metric.items():
        sp_corr=spearmanr(dist1, dist2)
        pe_corr=pearsonr(dist1, dist2)
        spearman_row.append(round(sp_corr.correlation, 4))
        pearson_row.append(round(pe_corr[0], 4))
        
    pearson_correlations.append(pearson_row)
    spearman_correlations.append(spearman_row)

# %%
def print_matrix(A):
    print('\n'.join(['\t'.join(['{:7}'.format(item) for item in row]) 
      for row in A]))

# %%
print_matrix(pearson_correlations)
# Out:
#        	js_div 	js_dist	kl_div 	kl_max 	kl_avg 	cos
# js_div 	    1.0	 0.9855	 0.8529	 0.8948	 0.9332	 0.9955
# js_dist	 0.9855	    1.0	 0.8486	  0.883	 0.9184	 0.9878
# kl_div 	 0.8529	 0.8486	    1.0	 0.9933	 0.9774	  0.868
# kl_max 	 0.8948	  0.883	 0.9933	    1.0	 0.9944	 0.9033
# kl_avg 	 0.9332	 0.9184	 0.9774	 0.9944	    1.0	 0.9392
# cos    	 0.9955	 0.9878	  0.868	 0.9033	 0.9392	    1.0

# %%
print_matrix(spearman_correlations)
# Out:
#        	js_div 	js_dist	kl_div 	kl_max 	kl_avg 	cos
# js_div 	    1.0	    1.0	 0.8936	 0.9119	  0.924	  0.997
# js_dist	    1.0	    1.0	 0.8936	 0.9119	  0.924	  0.997
# kl_div 	 0.8936	 0.8936	    1.0	 0.9758	 0.9515	  0.903
# kl_max 	 0.9119	 0.9119	 0.9758	    1.0	 0.9879	 0.9152
# kl_avg 	  0.924	  0.924	 0.9515	 0.9879	    1.0	 0.9273
# cos    	  0.997	  0.997	  0.903	 0.9152	 0.9273	    1.0

# %%
for prop, data in div_known.items():
    for known_props, dists in data.items():
        uncs=uncertainties[prop][known_props]
        print(prop, '\t', known_props, '\t', round(sum(dists)/len(dists),2), '\t', 
              round(sum(uncs)/len(uncs), 4))
# Out:
# century 	 3 	 0.04 	 0.0299
# century 	 4 	 0.06 	 0.0161
# century 	 5 	 0.1 	 0.0241
# century 	 6 	 0.22 	 0.0045
# century 	 7 	 0.5 	 0.0028
# century 	 8 	 0.4 	 0.0046
# century 	 9 	 1.0 	 0.0
# religion 	 3 	 0.04 	 0.0296
# religion 	 4 	 0.06 	 0.0237
# religion 	 5 	 0.08 	 0.0212
# religion 	 6 	 0.06 	 0.0174
# religion 	 7 	 0.02 	 0.0125
# religion 	 8 	 0.02 	 0.01
# gender 	 3 	 0.01 	 0.03
# gender 	 4 	 0.01 	 0.026
# gender 	 5 	 0.01 	 0.0297
# gender 	 6 	 0.0 	 0.013
# gender 	 7 	 0.0 	 0.0039
# lifedur 	 3 	 0.15 	 0.0276
# lifedur 	 4 	 0.16 	 0.0178
# lifedur 	 5 	 0.13 	 0.0209
# deathplace 	 3 	 0.49 	 0.1102
# deathplace 	 4 	 0.22 	 0.125
# deathplace 	 5 	 0.15 	 0.0953
# deathplace 	 6 	 0.17 	 0.0776
# birthplace 	 3 	 0.51 	 0.0997
# birthplace 	 4 	 0.44 	 0.0554
# birthplace 	 5 	 0.36 	 0.0311
# worklocation 	 3 	 0.34 	 0.086
# worklocation 	 4 	 0.45 	 0.1609
# worklocation 	 5 	 0.54 	 0.1133
# worklocation 	 6 	 0.48 	 0.1209
# occupation 	 3 	 0.43 	 0.1088
# occupation 	 4 	 0.53 	 0.0972
# occupation 	 5 	 0.56 	 0.094
# occupation 	 6 	 0.6 	 0.0899
# occupation 	 7 	 0.37 	 0.0293
# educatedat 	 3 	 0.42 	 0.1343
# educatedat 	 4 	 0.37 	 0.1224
# educatedat 	 5 	 0.34 	 0.1294
# educatedat 	 6 	 0.39 	 0.1182
# educatedat 	 7 	 0.57 	 0.1147
# educatedat 	 8 	 0.6 	 0.1097
# politicalparty 	 3 	 0.07 	 0.1394
# politicalparty 	 4 	 0.1 	 0.0634
# politicalparty 	 5 	 0.09 	 0.0695
# politicalparty 	 6 	 0.09 	 0.0661
# politicalparty 	 7 	 0.15 	 0.0494
# politicalparty 	 8 	 0.13 	 0.0267
# politicalparty 	 9 	 0.06 	 0.0667

# %% [markdown]
# ### 4. MFV baseline
#
# #### 4.1 Prepare

# %%
mfv_data_loc = 'mfv_data'
with open('%s/%s' % (mfv_data_loc, givens_file), 'rb') as f:
    mfv_givens=pickle.load(f)
with open('%s/%s' % (mfv_data_loc, predicted_file), 'rb') as f:
    mfv_preds = pickle.load(f)

# %%
new_mfv_givens=map_givens(mfv_givens)

# %%
new_mfv_preds=[]
for a_row in mfv_preds:
    new_row={}
    for prop, vals in a_row.items():
        prop=properties_mapping[prop]
        for k,v in vals.items():
            new_k=mappings[k]
            new_row[prop]={new_k: 1.0}
    new_mfv_preds.append(new_row)

# %% [markdown]
# #### 4.2 Evaluate

# %%
js_dist_mfv=[]
for metric in ['js_div','js_dist']:
    mfv_divs, div_known_mfv, uncertainties = \
        compute_divergencies(new_mfv_preds, new_crowd_preds, mfv_givens, props, metric=metric)
    mean_values=compute_mean_per_prop(mfv_divs)
    print(metric, mean_values)
    if metric == 'js_dist':
        for prop in props:
            js_dist_mfv.append(mean_values[prop])
# Out:
# js_div {'century': 0.13, 'religion': 0.05, 'gender': 0.04, 'deathplace': 0.51, 'lifedur': 0.29, 'birthplace': 0.39, 'worklocation': 0.49, 'occupation': 0.37, 'educatedat': 0.39, 'politicalparty': 0.17}
# js_dist {'century': 0.35, 'religion': 0.2, 'gender': 0.17, 'deathplace': 0.71, 'lifedur': 0.53, 'birthplace': 0.6, 'worklocation': 0.68, 'occupation': 0.6, 'educatedat': 0.62, 'politicalparty': 0.39}

# %% [markdown]
# ### 5. NB baseline
#
# #### 5.1 Prepare

# %%
nb_data_loc = 'nb_data'
with open('%s/%s' % (nb_data_loc, predicted_file), 'rb') as f:
    nb_preds = pickle.load(f, encoding='latin1')

# %%
nb_givens=new_mfv_givens

# %%
new_nb_preds=[]
for x in range(len(new_crowd_givens)):
    new_row={}
    these_givens=new_crowd_givens[x]
    for prop in nb_preds.keys():
        new_prop=properties_mapping[prop]
        new_value=defaultdict(float)
        if new_prop not in these_givens.keys():
            pred=nb_preds[prop][x]
            for k, v in pred.items():
                if k in mappings.keys() and mappings[k] in domains[new_prop]:
                    new_k=mappings[k]
                else:
                    new_k='None of the above'
                new_value[new_k] += v
            new_row[new_prop]=new_value
    new_nb_preds.append(new_row)

# %%
transposed_nb_predictions=accumulate_and_transpose(nb_givens, new_nb_preds)

# %% [markdown]
# #### 5.2 Evaluate

# %%
print(len(transposed_prof_predictions[0]))
# Out:
# 7

# %%
js_dist_nb=[]
for metric in ['js_div','js_dist']:
    nb_divs, div_known_nb, uncertainties = \
        compute_divergencies(transposed_nb_predictions, new_crowd_preds, 
                             nb_givens, props, metric=metric)
    mean_values=compute_mean_per_prop(nb_divs)
    print(metric, mean_values)
    if metric == 'js_dist':
        for prop in props:
            js_dist_nb.append(mean_values[prop])
# Out:
# js_div {'century': 0.12, 'religion': 0.09, 'gender': 0.02, 'deathplace': 0.2, 'lifedur': 0.09, 'birthplace': 0.26, 'worklocation': 0.28, 'occupation': 0.36, 'educatedat': 0.25, 'politicalparty': 0.06}
# js_dist {'century': 0.32, 'religion': 0.26, 'gender': 0.13, 'deathplace': 0.44, 'lifedur': 0.3, 'birthplace': 0.49, 'worklocation': 0.5, 'occupation': 0.59, 'educatedat': 0.49, 'politicalparty': 0.22}

# %% [markdown]
# ### 6. Compute correlation to entropy

# %%
entropy=[0.922, 1.256, 0.701, 2.403, 2.676, 2.477, 2.802, 2.903, 2.907, 0.998]
norm_entropy=[0.397, 0.628, 0.701, 0.801, 0.806, 0.826, 0.844, 0.916, 0.917, 0.998]
#js_dist_ae=[0.32, 0.27, 0.13, 0.44, 0.31, 0.5, 0.5, 0.59, 0.5, 0.23]
#js_dist_mfv=[0.36, 0.19, 0.16, 0.71, 0.53, 0.59, 0.68, 0.6, 0.62, 0.38]
#js_dist_nb=[0.57, 0.19, 0.16, 0.67, 0.58, 0.65, 0.68, 0.68, 0.62, 0.39]

for metric in [spearmanr, pearsonr]:
    print('entropy<->mfv', metric(entropy, js_dist_mfv))
    print('norm_entropy<->mfv', metric(norm_entropy, js_dist_mfv))

    print('entropy<->nb', metric(entropy, js_dist_nb))
    print('norm_entropy<->nb', metric(norm_entropy, js_dist_nb))

    print('entropy<->ae', metric(entropy, js_dist_ae))
    print('norm_entropy<->ae', metric(norm_entropy, js_dist_ae))
# Out:
# entropy<->mfv SpearmanrResult(correlation=0.8389096502784891, pvalue=0.0024139883688156136)
# norm_entropy<->mfv SpearmanrResult(correlation=0.5288778230016562, pvalue=0.11599132062584641)
# entropy<->nb SpearmanrResult(correlation=0.8571468165888911, pvalue=0.0015278398373375572)
# norm_entropy<->nb SpearmanrResult(correlation=0.4012176588288426, pvalue=0.25049600352532764)
# entropy<->ae SpearmanrResult(correlation=0.8267515394048879, pvalue=0.0031797140860104155)
# norm_entropy<->ae SpearmanrResult(correlation=0.43161293601284584, pvalue=0.21294529187580233)
# entropy<->mfv (0.9141402461350389, 0.00021412772985049123)
# norm_entropy<->mfv (0.5207227235390267, 0.12277788448332227)
# entropy<->nb (0.887903246196056, 0.0006021440093523258)
# norm_entropy<->nb (0.35791014872201793, 0.3098910465936598)
# entropy<->ae (0.8754719418492624, 0.0009028723003217823)
# norm_entropy<->ae (0.36204944106039, 0.3039199826887172)
